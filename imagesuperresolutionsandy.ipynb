# %% [markdown]
# <a href="https://colab.research.google.com/github/SandhyaAlagan/Msc-Project/blob/main/imagesuperresolutionsandy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Data loading and processing

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def load_high_res_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, [64, 64])
    # Preprocess high-resolution image as needed (e.g., normalization, etc.)
    imgs = tf.cast(img,dtype = tf.float32) / 255.0  # Normalize pixel values to [0, 1]
    return imgs

def create_low_res_image(high_res_image, scale_factor = 2):
    low_res_image = tf.image.convert_image_dtype(high_res_image, tf.uint8) * 255
    low_res_image = tf.image.resize(low_res_image, [64 // scale_factor, 64 // scale_factor], method=tf.image.ResizeMethod.BICUBIC)
    low_res_image = tf.image.convert_image_dtype(low_res_image, tf.float32)
    return low_res_image

def create_train_data_loader(image_folder, batch_size, scale_factor, shuffle=True):
    subfolders = [os.path.join(image_folder, folder) for folder in os.listdir(image_folder) if os.path.isdir(os.path.join(image_folder, folder))]

    high_res_image_paths = []
    for folder in subfolders:
        high_res_image_paths.extend([os.path.join(folder, file) for file in os.listdir(folder)])

    high_res_image_dataset = tf.data.Dataset.from_tensor_slices(high_res_image_paths)
    high_res_images = high_res_image_dataset.map(load_high_res_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    low_res_image_dataset = high_res_images.map(create_low_res_image,num_parallel_calls=tf.data.experimental.AUTOTUNE)
    return (high_res_images,low_res_image_dataset)

    #dataset = tf.data.Dataset.zip((low_res_image_dataset, high_res_image_dataset))
    #if shuffle:
        #dataset = dataset.shuffle(buffer_size=len(high_res_image_paths), reshuffle_each_iteration=True)

    #dataset = dataset.batch(batch_size)
    #dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    #return dataset



# Data loading and generation
image_folder = '/content/drive/MyDrive/imageresolution/imagedataset/DIV2K_train_HR'
batch_size = 1
scale_factor = 2  # Change this according to your desired downscaling factor

train_data_loader = create_train_data_loader(image_folder, batch_size, scale_factor)

# %%
(hRImages,lRImages) = train_data_loader
hRImagesNp = np.zeros((800,64,64,3),dtype = np.float32)
lRImagesNp = np.zeros((800,32,32,3),dtype = np.float32)

for i,x in enumerate(hRImages):
    hRImagesNp[i,:] = x

for i,x in enumerate(lRImages):
    lRImagesNp[i,:] = x

# %% [markdown]
# # Printing out the sample image using Transfer learning for reference

# %%
import tensorflow as tf
import tensorflow_hub as hub

# Load the ESRGAN model from TensorFlow Hub
model_url = "https://tfhub.dev/captain-pool/esrgan-tf2/1"  # Example ESRGAN model from TensorFlow Hub
model = hub.load(model_url)

# Preprocess your input image as described in the previous answer
input_image = tf.io.read_file('/content/drive/MyDrive/imageresolution/imagedataset/DIV2K_train_HR/DIV2K_train_HR/0003.png')
input_image = tf.image.decode_image(input_image, channels=3)
input_image = tf.image.convert_image_dtype(input_image, tf.float32)
input_image = tf.image.resize(input_image, (256, 256))

# Perform super-resolution
sr_image = model(input_image[tf.newaxis, ...])

# Post-process and save the result as described in the previous answer
sr_image = tf.squeeze(sr_image, axis=0)
sr_image = tf.clip_by_value(sr_image, 0.0, 1.0)
sr_image = tf.image.convert_image_dtype(sr_image, tf.uint8)
tf.io.write_file('output_image.jpg', tf.image.encode_jpeg(sr_image))

# %%
image_path = '/content/drive/MyDrive/imageresolution/imagedataset/DIV2K_valid_HR/DIV2K_valid_HR/0802.png'

# Read and decode the image from the file path
image = tf.io.read_file(image_path)
image = tf.image.decode_image(image, channels=3)  # Specify the number of color channels (e.g., 3 for RGB)

# You may want to resize or preprocess the image as needed
# For example, resizing it to a specific size
#image = tf.image.resize(image, [height, width])  # Replace height and width with your desired dimensions

# Convert the image tensor to a NumPy array for displaying
image = image.numpy()

# Display the image using Matplotlib
plt.imshow(image)
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# # Model building and training

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

class Discriminator(models.Model):
    def __init__(self):
        super(Discriminator, self).__init__()

        # Convolutional layers for feature extraction
        self.conv1 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation=tf.nn.leaky_relu)
        self.conv2 = layers.Conv2D(128, kernel_size=3, strides=2, padding='same', activation=tf.nn.leaky_relu)
        self.conv3 = layers.Conv2D(256, kernel_size=3, strides=2, padding='same', activation=tf.nn.leaky_relu)
        self.conv4 = layers.Conv2D(512, kernel_size=3, strides=2, padding='same', activation=tf.nn.leaky_relu)

        # Dense layer for binary classification
        self.flatten = layers.Flatten()
        self.dense = layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        # Forward pass through convolutional layers
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)

        # Flatten the feature maps
        x = self.flatten(x)

        # Perform binary classification
        x = self.dense(x)

        return x

# %%
from tensorflow.keras import layers, models, losses, optimizers

upsampling_factor = 4

# Define residual channel attention block (RCAB)
class RCAB(layers.Layer):
    def __init__(self, num_filters):
        super(RCAB, self).__init__()
        self.conv1 = layers.Conv2D(num_filters, kernel_size=3, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(num_filters, kernel_size=3, padding='same')
        self.channel_attention = ChannelAttention(num_filters)

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.channel_attention(x)
        return inputs + x

# Define channel attention mechanism
class ChannelAttention(layers.Layer):
    def __init__(self, num_filters):
        super(ChannelAttention, self).__init__()
        self.global_pool = layers.GlobalAveragePooling2D()
        self.dense1 = layers.Dense(num_filters // 16, activation='relu')
        self.dense2 = layers.Dense(num_filters)

    def call(self, inputs):
        # Global Average Pooling
        x = self.global_pool(inputs)
        x = layers.Reshape((1, 1, x.shape[-1]))(x)
        # Dense layers
        x = self.dense1(x)
        x = self.dense2(x)
        # Apply sigmoid activation
        x = tf.nn.sigmoid(x)
        # Apply attention
        return inputs * x


# Generator (Enhancement Network) for ESRGAN
def make_generator_model(scale_factor, num_rcabs = 10, num_filters = 64):
    # Input: Low-resolution image
    inputs = layers.Input(shape=(None, None, 3))

    # Feature extraction layers
    x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(inputs)
    x = layers.Conv2D(64, kernel_size=3, padding='same', activation='relu')(x)

    # Residual blocks
    for _ in range(16):
        residual = x
        x = layers.Conv2D(64, kernel_size=3, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(64, kernel_size=3, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Add()([x, residual])

    # Upscaling layer using sub-pixel convolution (PixelShuffle)
    x = layers.Conv2D(256, kernel_size=3, padding='same')(x)
    x = layers.Lambda(lambda x: tf.nn.depth_to_space(x, scale_factor))(x)

    # Output: High-resolution image
    outputs = layers.Conv2D(3, kernel_size=3, padding='same', activation='sigmoid')(x)

    return models.Model(inputs, outputs)

# Discriminator for ESRGAN
def make_discriminator_model():
    inputs = layers.Input(shape=(None, None, 3))

    x = layers.Conv2D(64, kernel_size=3, strides=1, padding='same', activation='relu')(inputs)
    x = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, kernel_size=3, strides=1, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    x = layers.Conv2D(256, kernel_size=3, strides=1, padding='same', activation='relu')(x)
    x = layers.Conv2D(256, kernel_size=3, strides=2, padding='same', activation='relu')(x)

    x = layers.GlobalAveragePooling2D()(x)  # Flatten the output
    x = layers.Dense(1024, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    return models.Model(inputs, outputs)


# ESRGAN model combining Generator and Discriminator
def make_esrgan_model(scale_factor):
    # Set the trainable property for Discriminator to False
    discriminator = make_discriminator_model()
    discriminator.trainable = False

    # Input: Low-resolution image
    inputs_lr = layers.Input(shape=(None, None, 3))

    # Generate high-resolution image using Generator
    generated_hr = make_generator_model(scale_factor)(inputs_lr)

    # Discriminator evaluates generated HR images
    validity = discriminator(generated_hr)

    return models.Model(inputs_lr, [generated_hr, validity])

# Create an instance of the ESRGAN model
scale_factor = 2  # Set your desired upscaling factor
esrgan_model = make_esrgan_model(scale_factor)

# Compile the ESRGAN model with appropriate loss and optimizer
criterion_gen = losses.MeanSquaredError()
criterion_disc = losses.BinaryCrossentropy()
optimizer_gen = optimizers.Adam(lr=1e-4)
optimizer_disc = optimizers.Adam(lr=1e-4)

esrgan_model.compile(optimizer=[optimizer_gen, optimizer_disc],
                     loss=[criterion_gen, criterion_disc],
                     loss_weights=[1, 0.01])

# Assuming you have low-resolution and high-resolution image tensors for training
train_low_res_images = lRImagesNp[:600]
train_high_res_images = hRImagesNp[:600]
validation_low_res_images = lRImagesNp[600:800]
validation_high_res_images = hRImagesNp[600:800]


best_gen_loss = float('inf')
best_gen_weights = None

# Lists to store training and validation losses of each epoch
training_losses = []
validation_losses = []

# Create TensorFlow datasets from the tensors
batch_size = 16
train_dataset = tf.data.Dataset.from_tensor_slices((train_low_res_images, train_high_res_images)).shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices((validation_low_res_images, validation_high_res_images)).shuffle(buffer_size=1000).batch(batch_size).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# Define the number of training epochs
num_epochs = 100

epoch_training_loss = []
# Training loop
for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}/{num_epochs}")

    # Training
    for batch_low_res, batch_high_res in train_dataset:
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            # Generate high-resolution images
            generated_hr, validity = esrgan_model(batch_low_res, training=True)
            print("Generated HR and Validity")
            # Calculate Generator loss
            print(batch_high_res.shape)
            print(generated_hr.shape)
            loss_gen = criterion_gen(batch_high_res, generated_hr)
            print("Generator loss ",loss_gen)

            # Calculate Discriminator loss
            loss_disc_real = criterion_disc(tf.ones_like(validity), validity)
            loss_disc_fake = criterion_disc(tf.zeros_like(validity), validity)
            loss_disc = 0.5 * (loss_disc_real + loss_disc_fake)
            print("Discriminator loss ",loss_disc)

        # Backpropagation and optimizer steps
        gradients_gen = gen_tape.gradient(loss_gen, esrgan_model.trainable_variables)
        gradients_disc = disc_tape.gradient(loss_disc, esrgan_model.trainable_variables)
        optimizer_gen.apply_gradients(zip(gradients_gen, esrgan_model.trainable_variables))
        optimizer_disc.apply_gradients(zip(gradients_disc, esrgan_model.trainable_variables))

    epoch_training_loss.append(loss_gen.numpy())
    avg_training_loss = sum(epoch_training_loss) / len(epoch_training_loss)
    training_losses.append(avg_training_loss)

    epoch_validation_loss = []
    for batch_low_res_val, batch_high_res_val in val_dataset:
        # Generate high-resolution images
        generated_hr_val, _ = esrgan_model(batch_low_res_val, training=False)

        # Calculate Generator loss for validation
        loss_gen_val = criterion_gen(batch_high_res_val, generated_hr_val)

        # Append the batch loss to the epoch_validation_loss list
        epoch_validation_loss.append(loss_gen_val.numpy())

    # Calculate average validation loss for the epoch
    avg_validation_loss = sum(epoch_validation_loss) / len(epoch_validation_loss)
    validation_losses.append(avg_validation_loss)

    # Print and save best model based on generator loss
    print(f"Gen Loss: {avg_training_loss:.4f}, Val Loss: {avg_validation_loss:.4f}")

    if avg_training_loss < best_gen_loss:
        best_gen_loss = avg_training_loss
        esrgan_model.layers[1].save_weights('best_esrgan_generator.h5')

print("Training finished.")
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Streaming output truncated to the last 5000 lines.
# Discriminator loss  tf.Tensor(0.69317687, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.17811067, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931899, shape=(), dtype=float32)
# Gen Loss: 0.1489, Val Loss: 0.1734
# Epoch 75/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16449797, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931686, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18825549, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317645, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1602993, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931788, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17922884, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317436, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16823395, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317037, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16030473, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931642, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18295693, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931716, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18486643, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318044, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14603215, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317335, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16631354, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69316924, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14627784, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693187, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17447893, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693183, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13947846, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931745, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15109666, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931754, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11891839, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931782, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16964793, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318247, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14927602, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15622264, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318485, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14452064, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318277, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1583058, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931979, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14219354, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931877, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1519006, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932065, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14365351, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319427, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14373629, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931929, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1357426, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931925, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13065995, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319534, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13631482, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319844, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15424834, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317377, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14443767, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931895, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14034851, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317794, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16275443, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931844, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14636256, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931752, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1460118, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317764, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1560266, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931772, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.19143248, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931794, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18347949, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317484, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1626238, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931946, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.13415425, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931826, shape=(), dtype=float32)
# Gen Loss: 0.1487, Val Loss: 0.1701
# Epoch 76/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16560474, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931785, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11089464, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317424, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15172619, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931745, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16358113, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931747, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16543563, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317377, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1592318, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317096, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1568915, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931672, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15497734, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931846, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15536848, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931788, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13900514, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931678, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.19239372, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317114, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14391229, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69316626, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17348644, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318163, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17236786, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931812, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14989018, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318485, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14169286, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693183, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16620736, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931795, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15403795, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931797, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14198075, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931908, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13985646, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931912, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.209907, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319797, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16405016, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932045, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14373174, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319224, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14929937, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931957, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14598018, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320667, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15971383, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932056, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1445477, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931941, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14195006, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931914, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15884034, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931946, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16728856, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932143, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18152168, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931959, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13219514, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931878, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16497114, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12914701, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318813, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14683521, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318986, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16145733, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318646, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15315685, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931845, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.1675336, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931967, shape=(), dtype=float32)
# Gen Loss: 0.1490, Val Loss: 0.1483
# Epoch 77/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15730947, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318783, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14919783, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320995, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13758746, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932006, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12996954, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14272505, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319606, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12398883, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320047, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15006883, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932148, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1586285, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931961, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13471086, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319934, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13820146, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931877, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18178502, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319975, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16873947, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319224, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15039808, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931939, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18733254, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932013, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14524493, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693189, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14004594, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319904, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13984048, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932101, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13222507, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932038, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14284247, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321287, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13795343, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932094, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14951088, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319993, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11682807, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319904, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1478746, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320476, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14139242, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319546, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1338639, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319534, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13030046, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931973, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.129641, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932006, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12871316, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931987, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14752783, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321287, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14577004, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321346, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13399315, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320166, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1309294, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932081, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14720282, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932073, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13747792, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931975, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14283893, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932099, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1476816, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932052, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14480224, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932057, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.1204487, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318295, shape=(), dtype=float32)
# Gen Loss: 0.1486, Val Loss: 0.1657
# Epoch 78/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12192731, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693202, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12581073, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693189, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13233754, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932055, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.123131804, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932062, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15204406, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931913, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1467411, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931936, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14209652, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931992, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12875162, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932111, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12936153, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932058, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16269067, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320345, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12989323, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931888, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15869215, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932015, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13918293, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931962, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17022705, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932097, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13592444, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693189, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1295175, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932065, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13476378, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932025, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12705845, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932025, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15909052, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320273, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13016015, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932082, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12445852, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932062, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13434185, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931935, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13736063, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320005, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14902961, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932054, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14912537, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318265, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1457213, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932092, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13347867, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319654, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14966963, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931991, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16142644, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931911, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12965402, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319844, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16150329, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932025, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11580082, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932283, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1657397, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319755, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18413678, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931969, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14435855, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932001, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15689847, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932144, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12999347, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932131, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.14193532, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321823, shape=(), dtype=float32)
# Gen Loss: 0.1485, Val Loss: 0.1568
# Epoch 79/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14693025, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693199, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1335929, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932224, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14312543, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693221, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14120287, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932272, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1632106, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320524, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13505727, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321275, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.124669686, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931994, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14188021, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932132, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14984214, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931915, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13298975, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932001, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1407345, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693192, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1429904, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319594, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13065517, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931921, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14692135, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319934, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13377804, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932112, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15754524, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320107, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14337313, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693195, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1191124, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693195, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15728882, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319546, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15446335, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931859, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16299197, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318515, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15683404, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931799, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1736511, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931979, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1612431, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931921, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15698092, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931823, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14850274, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932103, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13815343, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931944, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13681914, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932049, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15781781, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693208, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14373419, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320726, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17169139, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320345, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14355774, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320595, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13717434, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320434, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1375024, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932029, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16695535, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320714, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13482188, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931995, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15108979, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931979, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.13427661, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69317853, shape=(), dtype=float32)
# Gen Loss: 0.1483, Val Loss: 0.1587
# Epoch 80/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16966943, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320905, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12040596, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318897, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14034992, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931907, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14891775, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932071, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13445024, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931919, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1324903, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318706, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14817587, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693204, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14716117, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931981, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13958436, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932045, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14117247, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319177, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13060685, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319963, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1380269, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319814, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13446036, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932086, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1107548, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693199, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14650959, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932213, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15026547, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320077, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16159253, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319606, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13498029, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932218, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1721914, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321454, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13843162, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932207, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13617605, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932004, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12522686, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932204, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12382938, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320333, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14114821, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322884, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14953656, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932241, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1390787, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932302, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11474986, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932268, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14584157, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932344, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13925008, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932174, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15375361, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321096, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15147147, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693217, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13512231, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932229, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13541268, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932267, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16707778, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693229, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.121110365, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321823, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14604692, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321203, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15677679, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320166, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.21003959, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932004, shape=(), dtype=float32)
# Gen Loss: 0.1491, Val Loss: 0.1477
# Epoch 81/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14074646, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693193, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14171171, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931908, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13801244, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932062, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14670424, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931927, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13149092, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318485, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15150326, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932019, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14355943, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1301248, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931938, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16539283, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931954, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13815014, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931925, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13794315, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931808, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17395341, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931849, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14188436, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318956, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14500235, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319975, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15192774, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11794661, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932074, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15067995, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319904, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15056247, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15028667, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320846, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15045196, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932024, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16714174, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931933, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14327079, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932161, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13500416, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932264, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# ...
# Discriminator loss  tf.Tensor(0.6932067, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.19201373, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932058, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13493413, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320905, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13448507, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319195, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16654696, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320226, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14837763, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69318664, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16439185, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320047, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18428978, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320226, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.1521063, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932086, shape=(), dtype=float32)
# Gen Loss: 0.1495, Val Loss: 0.1556
# Epoch 99/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16299768, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320333, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14802259, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320273, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14707246, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932105, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13886237, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931969, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14946422, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320273, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17607033, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320023, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14921173, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932286, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14487708, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932008, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1506545, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931945, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14628722, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932005, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13794613, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932101, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15440731, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320524, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15297921, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932101, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14908102, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321024, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15151869, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931907, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.16057195, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932076, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1625806, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322926, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15770957, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321465, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13800938, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932107, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15042637, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931992, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1749919, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931995, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1387565, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319594, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1687625, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932082, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15063787, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931975, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12978819, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320774, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12571076, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320476, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15049472, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15056923, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320637, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13388506, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932025, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.162083, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320035, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1338613, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931969, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14838895, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319594, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.18344773, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319856, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15692952, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320226, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12553996, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932033, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15806812, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320023, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1473922, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320583, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.1711581, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319606, shape=(), dtype=float32)
# Gen Loss: 0.1497, Val Loss: 0.1640
# Epoch 100/100
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15006246, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693209, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17365482, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319904, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15559018, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931882, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14028099, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321096, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1444383, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932033, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.121185824, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932188, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13999096, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320166, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.11989263, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931977, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14403443, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319904, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1766924, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321203, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14125663, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319993, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12823546, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321007, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15110219, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320095, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1513969, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932233, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14706987, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320047, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15384331, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322073, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15272662, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321233, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15297207, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321895, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13371268, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321203, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12535551, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6931969, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14350113, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322234, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13989921, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322115, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15333083, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322085, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13758527, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932231, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14160123, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932146, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.17962706, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932101, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14301041, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932188, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14688924, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932343, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1392287, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69320923, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.12969561, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321525, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1517459, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932206, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13364637, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.693221, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.10718564, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322324, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.13883117, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69322085, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.15383688, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932229, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.14928997, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69321835, shape=(), dtype=float32)
# Generated HR and Validity
# (16, 64, 64, 3)
# (16, 64, 64, 3)
# Generator loss  tf.Tensor(0.1651755, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.6932208, shape=(), dtype=float32)
# Generated HR and Validity
# (8, 64, 64, 3)
# (8, 64, 64, 3)
# Generator loss  tf.Tensor(0.14408736, shape=(), dtype=float32)
# Discriminator loss  tf.Tensor(0.69319266, shape=(), dtype=float32)
# Gen Loss: 0.1496, Val Loss: 0.1594
# Training finished.

# %% [markdown]
# # Plotting the training and validation loss

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the training_losses and validation_losses lists from the training process

# Function to calculate moving average
def moving_average(data, window_size):
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

# Set the window size for moving average
window_size = 2

# Calculate moving average of training and validation losses
training_losses_moving_avg = moving_average(training_losses, window_size)
validation_losses_moving_avg = moving_average(validation_losses, window_size)

# Create a list of epochs for the x-axis
epochs = list(range(window_size, num_epochs + 1))

# Plot the moving average of training loss vs. validation loss
plt.plot(epochs, training_losses_moving_avg, label='Training Loss (Moving Avg)')
plt.plot(epochs, validation_losses_moving_avg, label='Validation Loss (Moving Avg)')

plt.xlabel('Epochs')
plt.ylabel('Loss (Moving Avg)')
plt.title('Training Loss vs. Validation Loss (Moving Avg)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Saving the best version of the model

# %%
# Define the path in Google Drive to save the model
model_path = '/content/drive/MyDrive/imageresolution'

# Save the entire model to Google Drive
tf.saved_model.save(model, model_path)
